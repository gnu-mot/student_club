# %% [markdown]
# # **2022년 빅데이터 동아리 특강 - 오리엔테이션 (2022년 7월 18일)**
#
# 대학원 기술경영학과 (Management of Technology) - 송지훈 교수

# %% [markdown]
# 🧑👩 학생 여러분, 빅데이터 동아리에 오신걸 환영합니다 !\
# 짧은 시간이지만, 여러분들이 다양한 특강을 기반으로 **스스로 학습** 및 **경진대회**에 **참가** 할 수 있는 **역량**을 갖출 수 있도록 지원하는게 주 목적 입니다.

# %% [markdown]
# **나중을 위한 팁**\
# ✅ You can only learn data science by doing data science. (실제로 코드를 구현해 봐야 합니다 ~) \
# ✅ Practice, practice, practice. (연습하고 또 연습하세요, 짧은 강의시간에 모든 세세한 내용을 전부 다룰수 없습니다 + 끊임없는 연습만이 완벽함을 만듭니다. )\
# ✅ Free resources everywhere. (인터넷상에는 무료로 데이터 분석 또는 프로그래밍 관련 공부를 할 수 있는 많은 자료들이 존재 합니다. 적극적으로 찾아서 이용하세요.)

# %% [markdown]
# # **방학 중 동아리 활동 계획**
#
# 1. 국가공인 데이터분석 전문가 관련 문제 풀이 --> 파이썬 중급 및 pandas 활용법
#
# * (https://www.dataq.or.kr/www/sub/a_05.do , https://www.dataq.or.kr/www/main.do)
#
# 2. 개별 프로젝트 지도

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 참조 웹사이트 (https://www.kaggle.com/datasets/agileteam/bigdatacertificationkr)

# %% [markdown]
# ## **문제1**
#
# (1) 주어진 데이터셋(big_practice1.csv)의 'f5' 컬럼을 기준으로 상위 10개의 데이터를 구하고\
# (2) 'f5'컬럼 10개 중 최소값으로 데이터를 대체한 후\
# (3) 'age'컬럼에서 80 이상인 데이터의 'f5' 컬럼 평균값 구하기

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/gnu-mot/student_club/main/big_practice1.csv')

# %%
df.shape # shape의 의미는?

# %%
df.info() # info()를 통해 얻고자 하는 정보는?

# %%
# 결측치를 확이하는 방법
df.isnull().sum()

# %%
df.head() # 여기까지는 항상 기본적인 스텝, 어떤 데이터인지 파악
# 어떤 데이터 인가요?

# %%
df.describe() # 어떤 의미를 가지는가?

# %%
col_list = df.columns.tolist() # 컬럼명을 리스트화해 저장이 가능
col_list

# %%
df['age'].unique() # age 컬럼의 유니크한 값을 반환 (확인하는 이유? 확인해야하는 이유가 있다면?)

# %%
df['age'].nunique() # age 컬럼에 있는 유니크한 값의 갯수를 반환

# %% [markdown]
# * 'f5' 컬럼을 기준으로 상위 10개의 데이터를 구하기

# %%
high_to_low = df.sort_values('f5', ascending=False) # ascending 의 반대말은 descending이지만, descending은 없음, ascending = False는 내림차순으로 정렬
high_to_low.head(10)

# %%
low_to_high = df.sort_values('f5', ascending=True) # ascending = True는 오름차순으로 정렬
low_to_high.head(10)

# %%
# 실제 시험에서는 같은 이름으로 데이터 프레임을 정의해야 할 수도 있음
df = df.sort_values('f5', ascending=False)
df.head(10)

# %% [markdown]
# *  'f5'컬럼 10개 중 최소값으로 데이터를 대체

# %%
# 정렬된 상위 10개의 값 중 최소값 찾기
min = high_to_low['f5'][:10].min()
min

# %%
# 상위 10개의 값을 대체하기
high_to_low['f5'][:10] = min
high_to_low.head(10)

# %% [markdown]
# * age 컬럼에서 80 이상인 데이터의 'f5' 컬럼 평균값 구하기

# %%
high_to_low[high_to_low['age']>=80] # age가 80이상의 값들만 포함시킨 데이터 프레임

# %%
result = high_to_low[high_to_low['age']>=80]['f5'].mean()
print(result)

# %% [markdown]
# ## **문제2**
#
# (1) 주어진 데이터셋(big_practice1.csv)의 앞에서 순서대로 70% 데이터만 활용해서,
# 'f1'컬럼 결측치를 중앙값으로 채우기 전후의 표준편차를 구하고 두 표준편차 차이 계산하기

# %%
# 데이터를 새로 불러와서 진행 (시험 환경에서는)
df = pd.read_csv('https://raw.githubusercontent.com/gnu-mot/student_club/main/big_practice1.csv')

# %%
# 데이터 나누는 방법 1
data70 = df.iloc[:70]
data30 = df.iloc[70:]

# %%
data70.tail()

# %%
data30.head()

# %%
# 결측치를 확인하는 방법
data70.isnull().sum()

# %%
# 채우기 전 표준편차 구하기 (standard deviation)
std1 = data70['f1'].std()
std1

# %%
# 중앙값 계산하기 
median = data70['f1'].median()
median

# %%
# 중앙값으로 채우기
data70['f1'] = data70['f1'].fillna(median)

# %%
# 결측치 검토
# 채워진걸 확인
data70.isnull().sum()

# %%
# 결측치를 핸들링 한 후 표준편차 구하기
std2 = data70['f1'].std()
std2

# %%
# 결측치 차이 구하기
print(std1-std2)

# %%
# 추가적인 설명
# 데이터 나누는 방법 2
import numpy as np
data70, data30 = np.split(df, [int(.7*len(df))]) # int(.7*len(df)) ==> 70
data70

# %%
# 데이터 나누는 방법 3 (랜덤하게 데이터를 나누어야 할 때)
data70 = df.sample(frac = 0.7)
data30 = df.drop(data70.index)
data70 # index를 확인 (랜덤하게 분포)

# %% [markdown]
# ## **문제3**
#
# (1) 주어진 데이터셋(big_practice1.csv)의 'age'컬럼의 이상치를 더하시오!
# 단, 평균으로부터 '표준편차*1.5'를 벗어나는 영역을 이상치라고 판단함
#
# 이상치 = outlier (평균치에서 크게 벗어나서 다른 대상들과 확연히 구분되는 표본)

# %%
# 데이터를 새로 불러와서 진행 (시험 환경에서는)
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/gnu-mot/student_club/main/big_practice1.csv')

# %%
df.isnull().sum()

# %% [markdown]
# 표준편차와 관련된 내용은 여기서 확인: https://math100.tistory.com/9

# %%
std_pop = np.std(df['age']) * 1.5 # 모집단 (population) 분산의 측정 방식 (n)
print(std_pop)

# %%
std_sample = df['age'].std() * 1.5 # 표본(sample) 분산의 측정 방식 (n-1)
print(std_sample) # 이 값을 활용

# %%
std_pop = np.std(df['age'], ddof=1) * 1.5 # 표본(sample) 분산의 측정 방식 (n-1)
print(std_pop)

# %%
mean = df['age'].mean()

min_out = mean - std
max_out = mean + std
print(min_out, max_out)

# %% [markdown]
# 이상치(outlier)에 해당하는 값들만을 추출한 후 합하기

# %%
# 이상치만 표현
df[(df['age']> max_out)|(df['age']<min_out)]

# %%
# 이상치 age의 합
df[(df['age']> max_out)|(df['age']<min_out)]['age'].sum()

# %% [markdown]
# ## **추가문제 (3번 연계)**

# %%
# 이상치를 제외한 데이터 프레임을 만든다면
df[(df['age']> max_out)|(df['age']<min_out)].index

# %%
len(df[(df['age']> max_out)|(df['age']<min_out)].index)

# %%
removed_outlier = df.drop(df[(df['age']> max_out)|(df['age']<min_out)].index)
removed_outlier

# %% [markdown]
# ## **문제4**
#
# (1) 주어진 mtcars 데이터 셋에서 qsec 컬럼을 Min-Max Scale로 변환 후 0.5보다 큰 값을 가지는 레코드(row) 수를 묻는 문제.

# %% [markdown]
# 데이터셋에 대한 설명
#
# https://zetawiki.com/wiki/Mtcars_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%85%8B

# %%
import pandas as pd
data = pd.read_csv('https://gist.githubusercontent.com/ZeccaLehn/4e06d2575eb9589dbe8c365d61cb056c/raw/898a40b035f7c951579041aecbfb2149331fa9f6/mtcars.csv')

# %%
data.info()

# %%
data.columns.tolist()[0]

# %%
# 컬럼명 수정
data = data.rename(columns={'Unnamed: 0':'model'})

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.minmax_scale.html (공식참조)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# (https://wotres.tistory.com/entry/min-max-scaling-%ED%95%98%EB%8A%94-%EB%B0%A9%EB%B2%95-in-python)

# %%
# min-max scale을 위한 함수 생성
def minmax_function(data):
    res = (data - data.min()) / (data.max() - data.min())
    return res

# %%
data['qsec_scaled'] = minmax_function(data['qsec'])

# %%
data.head()

# %%
# 라이브러리를 활용
import pandas as pd
data = pd.read_csv('https://gist.githubusercontent.com/ZeccaLehn/4e06d2575eb9589dbe8c365d61cb056c/raw/898a40b035f7c951579041aecbfb2149331fa9f6/mtcars.csv')
data.head()

# %%
data.columns.tolist()[0]

# %%
# 컬럼명 수정
data = data.rename(columns={'Unnamed: 0':'model'})

# %%
data.shape

# %%
data.isnull().sum()

# %%
# qsec = 1/4 mile time
data['qsec'].head()

# %%
# Min-Max Scaling
# 정규화와 같은 의미. 
# 이 방법은 주어진 값을 0과 1사이로 축소시킨 것이다. 즉, 비율의 값을 가지게 되며 가장 작은 값은 0의 값을 가지게 될 것이고 가장 큰 값은 1의 값을 가질 것이다. 
from sklearn.preprocessing import minmax_scale

# min-max scale
data['qsec_scaled'] = minmax_scale(data['qsec'])
print('minmax 변환 후: \n',data['qsec_scaled'].head())

# %%
data[data['qsec_scaled']>0.5]

# %%
# 0.5보다 큰 값의 갯수 구하기
print(len(data[data['qsec_scaled']>0.5]))

# %%
# 이렇게도 사용
# 머신러닝을 위한 데이터 전처리 과정시 일반적으로 사용
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()
fitted = min_max_scaler.fit_transform(data[['qsec']])

# %%
data['qsec_minmax'] = fitted
data.head()

# %% [markdown]
# ## **문제5**
#
# (1) 이상치를 찾아라(IQR활용)
#
# (2) 주어진 데이터에서 IQR을 활용해 Fare컬럼의 이상치를 찾고, 이상치 데이터의 여성 수를 구하시오.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# http://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Boxplot_vs_PDF.svg/640px-Boxplot_vs_PDF.svg.png

# %%
import seaborn as sns
# titanic 데이터셋 가져오기
df = sns.load_dataset('titanic')
df.head()

# %%
df.shape

# %%
df.isnull().sum()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# https://www.simplypsychology.org/boxplots.html

# %%
# Box Plot
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
sns.boxplot(x= df['fare'])

# %%
# IQR 구하기
# quantile , 백분위수 구하기 (정확히말하면 4분위수)
Q1 = df['fare'].quantile(.25)
Q3 = df['fare'].quantile(.75)

# %%
IQR = Q3 - Q1

# %%
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)
print(lower_bound)
print(upper_bound)

# %%
print(df['fare'].min())

# %%
print(df['fare'].max())

# %%
outlier = df[(df['fare']<lower_bound) | (df['fare']>upper_bound)].reset_index(drop=False)

# %%
outlier['fare'].min()

# %%
len(outlier)

# %%
# 이상치 데이터에서 여성 수 구하기
print(len(outlier[outlier['sex'] == 'female']))

# %% [markdown]
# ## **추가문제 (5번 연계)**

# %%
from sklearn.ensemble import IsolationForest
model = IsolationForest(contamination=0.01, random_state=100)
# 데이터 세트의 이상값 비율 --> contamination

# %%
model.fit(df[['fare']])

# %%
pred =  model.predict(df[['fare']])

# %%
df['anomaly'] = pred

# %%
outliers= df.loc[df['anomaly']==-1]
outlier_index = list(outliers.index)

# %%
outlier_index

# %%
from sklearn.ensemble import IsolationForest
model2 = IsolationForest(random_state=10)
model2.fit(df[['fare']])

# %%
pred2 =  model2.predict(df[['fare']])
df['anomaly2'] = pred2
outliers2= df.loc[df['anomaly2']==-1]
outlier_index2 = list(outliers2.index)
print(len(outlier_index2))
